# %%
import os, sys, time
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import joblib
#import pickle
import pandas
import torch
sys.path.append("/Users/tizianocausin/Desktop/backUp20240609/summer2025/ponce_lab/exp_set/python_scripts/svcca")
import cca_core
from sklearn.cross_decomposition import CCA
from torchvision.models.feature_extraction import (
    create_feature_extractor,
    get_graph_node_names,
)
from datetime import datetime
sys.path.append("/Users/tizianocausin/Desktop/backUp20240609/summer2025/ponce_lab/exp_set/python_scripts/src")
from dim_redu_anns.utils import get_relevant_output_layers
from alignment.CCA import CCA_loop_within_mod

# %%
res_path = "/Users/tizianocausin/OneDrive - SISSA/data_repo/exp_set_res/silico"
model_name = "alexnet"
pooling = "maxpool"
num_components = 50
CCA_loop_within_modd(model_name, pooling, num_components, True, res_path)
# Out:
# 09:23:12 starting loading features.0
# 09:23:23 finished loading features.0
# 09:23:23 starting loading features.4
# 09:23:30 finished loading features.4
# 09:23:30 starting layers features.4 vs features.0
# 09:23:30 CCA already exists for features.4 vs features.0  at /Users/tizianocausin/OneDrive - SISSA/data_repo/exp_set_res/silico/cca_alexnet_maxpool/cca_alexnet_50_components_features.4_vs_features.0.pkl
# 09:23:31 features.4 vs features.0 corr 0.41
# 09:23:31 starting loading features.7
# 09:23:31 finished loading features.7
# 09:23:31 starting layers features.7 vs features.0
# 09:23:31 CCA already exists for features.7 vs features.0  at /Users/tizianocausin/OneDrive - SISSA/data_repo/exp_set_res/silico/cca_alexnet_maxpool/cca_alexnet_50_components_features.7_vs_features.0.pkl
# 09:23:32 features.7 vs features.0 corr 0.282
# 09:23:32 starting layers features.7 vs features.4
# 09:23:32 CCA already exists for features.7 vs features.4  at /Users/tizianocausin/OneDrive - SISSA/data_repo/exp_set_res/silico/cca_alexnet_maxpool/cca_alexnet_50_components_features.7_vs_features.4.pkl
# 09:23:32 features.7 vs features.4 corr 0.587
# 09:23:32 starting loading features.9
# 09:23:32 finished loading features.9
# 09:23:32 starting layers features.9 vs features.0
# 09:23:32 CCA already exists for features.9 vs features.0  at /Users/tizianocausin/OneDrive - SISSA/data_repo/exp_set_res/silico/cca_alexnet_maxpool/cca_alexnet_50_components_features.9_vs_features.0.pkl
# 09:23:33 features.9 vs features.0 corr 0.206
# 09:23:33 starting layers features.9 vs features.4
# 09:23:33 CCA already exists for features.9 vs features.4  at /Users/tizianocausin/OneDrive - SISSA/data_repo/exp_set_res/silico/cca_alexnet_maxpool/cca_alexnet_50_components_features.9_vs_features.4.pkl
# 09:23:33 features.9 vs features.4 corr 0.434
# 09:23:33 starting layers features.9 vs features.7
# 09:23:33 CCA already exists for features.9 vs features.7  at /Users/tizianocausin/OneDrive - SISSA/data_repo/exp_set_res/silico/cca_alexnet_maxpool/cca_alexnet_50_components_features.9_vs_features.7.pkl
# 09:23:34 features.9 vs features.7 corr 0.634
# 09:23:34 starting loading features.11
# 09:23:34 finished loading features.11
# 09:23:34 starting layers features.11 vs features.0
# 09:23:34 CCA already exists for features.11 vs features.0  at /Users/tizianocausin/OneDrive - SISSA/data_repo/exp_set_res/silico/cca_alexnet_maxpool/cca_alexnet_50_components_features.11_vs_features.0.pkl
# 09:23:34 features.11 vs features.0 corr 0.185
# 09:23:34 starting layers features.11 vs features.4
# 09:23:34 CCA already exists for features.11 vs features.4  at /Users/tizianocausin/OneDrive - SISSA/data_repo/exp_set_res/silico/cca_alexnet_maxpool/cca_alexnet_50_components_features.11_vs_features.4.pkl
# 09:23:35 features.11 vs features.4 corr 0.461
# 09:23:35 starting layers features.11 vs features.7
# 09:23:35 CCA already exists for features.11 vs features.7  at /Users/tizianocausin/OneDrive - SISSA/data_repo/exp_set_res/silico/cca_alexnet_maxpool/cca_alexnet_50_components_features.11_vs_features.7.pkl
# 09:23:35 features.11 vs features.7 corr 0.646
# 09:23:35 starting layers features.11 vs features.9
# 09:23:35 CCA already exists for features.11 vs features.9  at /Users/tizianocausin/OneDrive - SISSA/data_repo/exp_set_res/silico/cca_alexnet_maxpool/cca_alexnet_50_components_features.11_vs_features.9.pkl
# 09:23:36 features.11 vs features.9 corr 0.747
# 09:23:36 starting loading classifier.2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       3 pooling = "maxpool"
#       4 num_components = 50
# ----> 5 CCA_loop_within_modd(model_name, pooling, num_components, True, res_path)
#
# Cell In[5], line 14, in CCA_loop_within_modd(model_name, pooling, num_components, pca_option, res_path)
#       8 feats_path1 = f"{res_path}/imagenet_val_{model_name}_{target_layer1}_{pooling}_features.pkl"
#       9 print(
#      10     datetime.now().strftime("%H:%M:%S"),
#      11     f"starting loading {target_layer1}",
#      12     flush=True
#      13 )
# ---> 14 all_acts1 = joblib.load(feats_path1)
#      15 print(
#      16     datetime.now().strftime("%H:%M:%S"),
#      17     f"finished loading {target_layer1}",
#      18     flush=True
#      19 )
#      20 if pca_option==True:
#
# File ~/Desktop/virtual_envs/ponce_env/lib/python3.12/site-packages/joblib/numpy_pickle.py:736, in load(filename, mmap_mode, ensure_native_byte_order)
#     734 else:
#     735     with open(filename, "rb") as f:
# --> 736         with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737             fobj,
#     738             validated_mmap_mode,
#     739         ):
#     740             if isinstance(fobj, str):
#     741                 # if the returned file object is a string, this means we
#     742                 # try to load a pickle file generated with an version of
#     743                 # Joblib so we load it with joblib compatibility function.
#     744                 return load_compatibility(fobj)
#
# File ~/anaconda3/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/Desktop/virtual_envs/ponce_env/lib/python3.12/site-packages/joblib/numpy_pickle_utils.py:157, in _validate_fileobject_and_memmap(fileobj, filename, mmap_mode)
#     132 """Utility function opening the right fileobject from a filename.
#     133
#     134 The magic number is used to choose between the type of file object to open:
#    (...)    154
#     155 """
#     156 # Detect if the fileobj contains compressed data.
# --> 157 compressor = _detect_compressor(fileobj)
#     158 validated_mmap_mode = mmap_mode
#     160 if compressor == "compat":
#     161     # Compatibility with old pickle mode: simply return the input
#     162     # filename "as-is" and let the compatibility function be called by the
#     163     # caller.
#
# File ~/Desktop/virtual_envs/ponce_env/lib/python3.12/site-packages/joblib/numpy_pickle_utils.py:104, in _detect_compressor(fileobj)
#     100 max_prefix_len = _get_prefixes_max_len()
#     101 if hasattr(fileobj, "peek"):
#     102     # Peek allows to read those bytes without moving the cursor in the
#     103     # file which.
# --> 104     first_bytes = fileobj.peek(max_prefix_len)
#     105 else:
#     106     # Fallback to seek if the fileobject is not peekable.
#     107     first_bytes = fileobj.read(max_prefix_len)
#
# KeyboardInterrupt:

# %%
res_path = "/Users/tizianocausin/OneDrive - SISSA/data_repo/exp_set_res/silico"
model_name = "alexnet"
pooling = "maxpool"
target_layer = "classifier.2"
num_components = 50
feats_path = f"{res_path}/imagenet_val_{model_name}_{target_layer}_{pooling}_features.pkl"
print(datetime.now().strftime("%H:%M:%S"))
all_acts = joblib.load(feats_path)
print(datetime.now().strftime("%H:%M:%S"))
# Out:
# 17:02:10
# 17:02:11

# %%
PCs_path =f"/Users/tizianocausin/OneDrive - SISSA/data_repo/exp_set_res/silico/imagenet_val_{model_name}_{target_layer}_max_pool_pca_model_1000_PCs.pkl"
PCs = joblib.load(PCs_path)

# %%
def CCA_loop_within_modd(model_name, pooling, num_components, pca_option, res_path):
    layer_names = get_relevant_output_layers(model_name)
    cca_dir = f"{res_path}/cca_{model_name}_{pooling}"
    os.makedirs(cca_dir, exist_ok=True)
    layers_RSA = np.zeros((len(layer_names),len(layer_names)))
    for layer_idx1 in range(len(layer_names)):
        target_layer1 = layer_names[layer_idx1]
        feats_path1 = f"{res_path}/imagenet_val_{model_name}_{target_layer1}_{pooling}_features.pkl"
        print(
            datetime.now().strftime("%H:%M:%S"),
            f"starting loading {target_layer1}",
            flush=True
        )
        all_acts1 = joblib.load(feats_path1)
        print(
            datetime.now().strftime("%H:%M:%S"),
            f"finished loading {target_layer1}",
            flush=True
        )
        if pca_option==True:
            if all_acts1.shape[1] > 1000:
                PCs_path1 =f"{res_path}/imagenet_val_{model_name}_{target_layer1}_{pooling}_pca_model_1000_PCs.pkl"
                print(
                    datetime.now().strftime("%H:%M:%S"),
                    f"starting loading PC1",
                    flush=True
                )
                PCs1 = joblib.load(PCs_path1)
                print(
                    datetime.now().strftime("%H:%M:%S"),
                    f"starting loading PC1",
                    flush=True
                ) 
                all_acts1 = all_acts1 @ PCs1.components_.T
                print(
                     datetime.now().strftime("%H:%M:%S"),
                     f"finished backprojecting in PCs1",
                     flush=True
                 ) 
                 
        for layer_idx2 in range(layer_idx1):
            target_layer2 = layer_names[layer_idx2]
            print(datetime.now().strftime("%H:%M:%S"), f"starting layers {target_layer1} vs {target_layer2}")
            feats_path2 = f"{res_path}/imagenet_val_{model_name}_{target_layer2}_{pooling}_features.pkl"
            all_acts2 = joblib.load(feats_path2)
            save_path = f"{cca_dir}/cca_{model_name}_{num_components}_components_{target_layer1}_vs_{target_layer2}.pkl"
            if pca_option==True:
                if all_acts2.shape[1] > 1000:
                     PCs_path2 =f"{res_path}/imagenet_val_{model_name}_{target_layer2}_{pooling}_pca_model_1000_PCs.pkl"
                     
                     PCs2 = joblib.load(PCs_path2)
                     all_acts2 = all_acts2 @ PCs2.components_.T
                     save_path = f"{cca_dir}/cca_{model_name}_{num_components}_components_pca_{target_layer1}_vs_{target_layer2}.pkl"
            if os.path.exists(save_path):
                print(
                    datetime.now().strftime("%H:%M:%S"),
                    f"CCA already exists for {target_layer1} vs {target_layer2}  at {save_path}",
                    flush=True
                )
                weights_dict = joblib.load(save_path)
                d1 = all_acts1 @ weights_dict["W1"]
                d2 = all_acts2 @ weights_dict["W2"]
                coefs_CCA = np.array([
                    np.corrcoef(d1[:, i], d2[:, i])[0, 1] for i in range(d1.shape[1])
                ])
                layers_RSA[layer_idx1, layer_idx2] = np.mean(coefs_CCA)
                print(datetime.now().strftime("%H:%M:%S"), f"{target_layer1} vs {target_layer2} corr {np.round(np.mean(coefs_CCA), 3)}", flush=True)
                
            else:
                print(
                     datetime.now().strftime("%H:%M:%S"),
                     f"starting CCA",
                     flush=True
                ) 
                cca = CCA(n_components = num_components)
                cca.fit(all_acts1, all_acts2)
                print(
                     datetime.now().strftime("%H:%M:%S"),
                     f"finished CCA fit in PCs1",
                     flush=True
                ) 
                weights_dict = {}
                weights_dict["W1"] = cca.x_weights_  # shape: (n_features1, n_components)
                weights_dict["W2"] = cca.y_weights_  # shape: (n_features2, n_components)

                # 3. Project the data manually (optional, equivalent to fit_transform)
                d1 = all_acts1 @ weights_dict["W1"]
                d2 = all_acts2 @ weights_dict["W2"]
                coefs_CCA = np.array([
                    np.corrcoef(d1[:, i], d2[:, i])[0, 1] for i in range(d1.shape[1])
                ])
                weights_dict["coefs"] = coefs_CCA
                joblib.dump(weights_dict, save_path)
                layers_RSA[layer_idx1, layer_idx2] = np.mean(coefs_CCA)
                print(datetime.now().strftime("%H:%M:%S"), f"{target_layer1} vs {target_layer2} corr {np.round(np.mean(coefs_CCA), 3)}", flush=True)
    csv_save_path = f"{cca_dir}/{model_name}_similarity_layers.csv"
    if pca_option == True:
        csv_save_path = f"{cca_dir}/{model_name}_similarity_layers_pca.csv"
    np.savetxt(csv_save_path, layers_RSA, delimiter=",")

# %%
save_path = "/Users/tizianocausin/Library/CloudStorage/OneDrive-SISSA/data_repo/exp_set_res/silico/cca_alexnet_maxpool/cca_alexnet_features.4_vs_features.0.pkl"
weights_dict = joblib.load(save_path)

# %%
print(weights_dict)
# Out:
# {'coef_x': array([[-0.03583545, -0.05630539, -0.08347899, ..., -0.06290043,
#         -0.03938869, -0.00992829],
#        [ 0.05283454,  0.09256389,  0.07206997, ...,  0.00584645,
#         -0.03608364, -0.02465426],
#        [ 0.00726674, -0.00554731,  0.03489156, ..., -0.03844388,
#          0.02075255,  0.00164938],
#        ...,
#        [ 0.01843106,  0.03295771,  0.00319669, ...,  0.82858772,
#          0.00195467, -0.0057529 ],
#        [-0.05249378, -0.00659862,  0.05160598, ...,  0.00091774,
#          0.82702361, -0.00169296],
#        [ 0.03275495, -0.04447183, -0.01064416, ..., -0.00268344,
#          0.00812235,  0.91263661]], shape=(192, 192)), 'invsqrt_xx': array([[ 4.13746834e+00,  2.42467518e-02, -2.16855389e-01, ...,
#         -2.41820415e-01, -1.81068724e-02,  1.52788629e-02],
#        [ 2.42467518e-02,  2.47400502e+00, -2.18510959e-02, ...,
#          2.12203241e-02,  5.12939771e-03,  2.91898658e-02],
#        [-2.16855389e-01, -2.18510959e-02,  4.92158821e+00, ...,
#         -1.41696848e-01, -1.18542993e-01,  2.10643211e-02],
#        ...,
#        [-2.41820415e-01,  2.12203241e-02, -1.41696848e-01, ...,
#          4.58395359e+00, -6.12759523e-02, -1.83508469e-02],
#        [-1.81068724e-02,  5.12939771e-03, -1.18542993e-01, ...,
#         -6.12759523e-02,  7.22914108e+00, -5.56085557e-02],
#        [ 1.52788629e-02,  2.91898658e-02,  2.10643211e-02, ...,
#         -1.83508469e-02, -5.56085557e-02,  7.58515200e+00]],
#       shape=(192, 192)), 'full_coef_x': array([[-0.03583545, -0.05630539, -0.08347899, ..., -0.06290043,
#         -0.03938869, -0.00992829],
#        [ 0.05283454,  0.09256389,  0.07206997, ...,  0.00584645,
#         -0.03608364, -0.02465426],
#        [ 0.00726674, -0.00554731,  0.03489156, ..., -0.03844388,
#          0.02075255,  0.00164938],
#        ...,
#        [ 0.01843106,  0.03295771,  0.00319669, ...,  0.82858772,
#          0.00195467, -0.0057529 ],
#        [-0.05249378, -0.00659862,  0.05160598, ...,  0.00091774,
#          0.82702361, -0.00169296],
#        [ 0.03275495, -0.04447183, -0.01064416, ..., -0.00268344,
#          0.00812235,  0.91263661]], shape=(192, 192)), 'full_invsqrt_xx': array([[ 4.13746834e+00,  2.42467518e-02, -2.16855389e-01, ...,
#         -2.41820415e-01, -1.81068724e-02,  1.52788629e-02],
#        [ 2.42467518e-02,  2.47400502e+00, -2.18510959e-02, ...,
#          2.12203241e-02,  5.12939771e-03,  2.91898658e-02],
#        [-2.16855389e-01, -2.18510959e-02,  4.92158821e+00, ...,
#         -1.41696848e-01, -1.18542993e-01,  2.10643211e-02],
#        ...,
#        [-2.41820415e-01,  2.12203241e-02, -1.41696848e-01, ...,
#          4.58395359e+00, -6.12759523e-02, -1.83508469e-02],
#        [-1.81068724e-02,  5.12939771e-03, -1.18542993e-01, ...,
#         -6.12759523e-02,  7.22914108e+00, -5.56085557e-02],
#        [ 1.52788629e-02,  2.91898658e-02,  2.10643211e-02, ...,
#         -1.83508469e-02, -5.56085557e-02,  7.58515200e+00]],
#       shape=(192, 192)), 'coef_y': array([[-0.15307523, -0.03022843, -0.32146915, ..., -0.04316382,
#         -0.07591357, -0.04706278],
#        [ 0.01224286,  0.02763022, -0.11554781, ...,  0.118796  ,
#          0.12096727,  0.13274674],
#        [-0.06064368,  0.00132159, -0.14561994, ..., -0.00784678,
#         -0.02970724,  0.03660607],
#        ...,
#        [ 0.00065087,  0.02127448, -0.00760225, ..., -0.03570398,
#         -0.01495355,  0.15562034],
#        [-0.00914481,  0.00276631, -0.04318746, ...,  0.0682144 ,
#          0.01680306, -0.06229257],
#        [-0.01531047,  0.02235547, -0.00140427, ..., -0.03068465,
#          0.00096669, -0.01346718]], shape=(64, 64)), 'invsqrt_yy': array([[ 3.45385225e+00, -2.05953599e-01, -1.87058575e-01, ...,
#         -2.09590608e-02, -4.31906312e-01, -3.04235369e-02],
#        [-2.05953599e-01,  6.19757244e+00,  3.22547409e-02, ...,
#          1.17269868e-02, -1.76668517e-01, -1.82357393e-02],
#        [-1.87058575e-01,  3.22547409e-02,  2.34180969e+00, ...,
#          1.25541388e-02, -3.86267517e-02, -4.82956267e-03],
#        ...,
#        [-2.09590608e-02,  1.17269868e-02,  1.25541388e-02, ...,
#          3.22537077e+00, -4.79931939e-02,  2.41218322e-02],
#        [-4.31906312e-01, -1.76668517e-01, -3.86267517e-02, ...,
#         -4.79931939e-02,  3.01135823e+00,  2.29586994e-02],
#        [-3.04235369e-02, -1.82357393e-02, -4.82956267e-03, ...,
#          2.41218322e-02,  2.29586994e-02,  2.83440313e+00]],
#       shape=(64, 64)), 'full_coef_y': array([[-0.15307523, -0.03022843, -0.32146915, ..., -0.04316382,
#         -0.07591357, -0.04706278],
#        [ 0.01224286,  0.02763022, -0.11554781, ...,  0.118796  ,
#          0.12096727,  0.13274674],
#        [-0.06064368,  0.00132159, -0.14561994, ..., -0.00784678,
#         -0.02970724,  0.03660607],
#        ...,
#        [ 0.00065087,  0.02127448, -0.00760225, ..., -0.03570398,
#         -0.01495355,  0.15562034],
#        [-0.00914481,  0.00276631, -0.04318746, ...,  0.0682144 ,
#          0.01680306, -0.06229257],
#        [-0.01531047,  0.02235547, -0.00140427, ..., -0.03068465,
#          0.00096669, -0.01346718]], shape=(64, 64)), 'full_invsqrt_yy': array([[ 3.45385225e+00, -2.05953599e-01, -1.87058575e-01, ...,
#         -2.09590608e-02, -4.31906312e-01, -3.04235369e-02],
#        [-2.05953599e-01,  6.19757244e+00,  3.22547409e-02, ...,
#          1.17269868e-02, -1.76668517e-01, -1.82357393e-02],
#        [-1.87058575e-01,  3.22547409e-02,  2.34180969e+00, ...,
#          1.25541388e-02, -3.86267517e-02, -4.82956267e-03],
#        ...,
#        [-2.09590608e-02,  1.17269868e-02,  1.25541388e-02, ...,
#          3.22537077e+00, -4.79931939e-02,  2.41218322e-02],
#        [-4.31906312e-01, -1.76668517e-01, -3.86267517e-02, ...,
#         -4.79931939e-02,  3.01135823e+00,  2.29586994e-02],
#        [-3.04235369e-02, -1.82357393e-02, -4.82956267e-03, ...,
#          2.41218322e-02,  2.29586994e-02,  2.83440313e+00]],
#       shape=(64, 64)), 'neuron_means1': array([[16.875029 ],
#        [20.19892  ],
#        [17.462675 ],
#        [11.628098 ],
#        [ 8.782567 ],
#        [11.797433 ],
#        [ 9.477242 ],
#        [ 7.6966033],
#        [15.598985 ],
#        [13.101894 ],
#        [12.151256 ],
#        [21.145878 ],
#        [16.05993  ],
#        [ 9.25158  ],
#        [11.15375  ],
#        [12.916664 ],
#        [11.196063 ],
#        [ 9.796296 ],
#        [ 1.7309008],
#        [12.622745 ],
#        [ 9.287837 ],
#        [17.754362 ],
#        [18.757563 ],
#        [11.763131 ],
#        [16.07498  ],
#        [12.229762 ],
#        [ 9.799813 ],
#        [14.896023 ],
#        [ 6.5176454],
#        [14.12036  ],
#        [13.827346 ],
#        [15.507034 ],
#        [ 8.354129 ],
#        [12.185313 ],
#        [10.531556 ],
#        [15.827476 ],
#        [ 9.993991 ],
#        [15.49305  ],
#        [ 9.6298   ],
#        [10.816009 ],
#        [16.842197 ],
#        [ 8.753228 ],
#        [13.70448  ],
#        [13.370555 ],
#        [12.255248 ],
#        [ 7.587171 ],
#        [14.08976  ],
#        [13.225254 ],
#        [16.121273 ],
#        [15.929959 ],
#        [15.077228 ],
#        [ 8.4068985],
#        [18.24405  ],
#        [10.762294 ],
#        [15.337356 ],
#        [ 4.316384 ],
#        [ 8.769189 ],
#        [18.198444 ],
#        [10.752277 ],
#        [ 7.727106 ],
#        [15.527306 ],
#        [10.436088 ],
#        [ 9.413203 ],
#        [ 6.1095843],
#        [ 6.1051807],
#        [11.212333 ],
#        [14.072515 ],
#        [ 9.554363 ],
#        [11.367859 ],
#        [15.985787 ],
#        [10.050706 ],
#        [16.505388 ],
#        [ 9.787318 ],
#        [ 7.837703 ],
#        [14.342729 ],
#        [11.768628 ],
#        [14.488781 ],
#        [10.649389 ],
#        [10.373495 ],
#        [11.014052 ],
#        [15.63596  ],
#        [11.85052  ],
#        [14.772855 ],
#        [10.314654 ],
#        [13.823189 ],
#        [14.53509  ],
#        [10.26311  ],
#        [12.500354 ],
#        [17.841412 ],
#        [11.293957 ],
#        [15.017021 ],
#        [12.451873 ],
#        [ 9.385961 ],
#        [ 8.506146 ],
#        [16.483862 ],
#        [13.761212 ],
#        [15.036054 ],
#        [13.223835 ],
#        [16.69296  ],
#        [11.803672 ],
#        [15.045718 ],
#        [11.82458  ],
#        [15.827477 ],
#        [ 9.43937  ],
#        [12.157581 ],
#        [14.187472 ],
#        [12.282288 ],
#        [15.84092  ],
#        [10.564274 ],
#        [ 9.870254 ],
#        [12.908649 ],
#        [14.972714 ],
#        [ 9.904427 ],
#        [16.005125 ],
#        [14.40664  ],
#        [ 7.7732716],
#        [20.181126 ],
#        [12.65255  ],
#        [ 9.994123 ],
#        [21.044123 ],
#        [13.586281 ],
#        [ 5.0019994],
#        [ 9.112257 ],
#        [ 8.427026 ],
#        [14.321237 ],
#        [ 9.672169 ],
#        [ 7.5091515],
#        [15.478597 ],
#        [ 8.144843 ],
#        [11.993573 ],
#        [ 8.7386465],
#        [14.553298 ],
#        [22.747793 ],
#        [21.613327 ],
#        [ 9.832231 ],
#        [16.958813 ],
#        [14.907272 ],
#        [14.752196 ],
#        [10.218434 ],
#        [ 9.419684 ],
#        [12.777978 ],
#        [17.155561 ],
#        [ 9.744481 ],
#        [13.522672 ],
#        [13.40084  ],
#        [ 8.360759 ],
#        [14.451438 ],
#        [15.193421 ],
#        [ 8.035511 ],
#        [10.181086 ],
#        [14.30577  ],
#        [ 8.97337  ],
#        [12.363524 ],
#        [18.771006 ],
#        [ 9.920911 ],
#        [19.705564 ],
#        [ 6.689745 ],
#        [12.978745 ],
#        [13.687874 ],
#        [21.17865  ],
#        [ 7.2820725],
#        [ 9.494626 ],
#        [ 9.981811 ],
#        [14.845338 ],
#        [ 7.326632 ],
#        [ 7.057091 ],
#        [ 8.16213  ],
#        [18.819145 ],
#        [16.940779 ],
#        [14.92744  ],
#        [15.599271 ],
#        [13.732015 ],
#        [12.335702 ],
#        [ 4.314341 ],
#        [ 5.3753934],
#        [ 7.9417787],
#        [10.063729 ],
#        [12.389121 ],
#        [12.010606 ],
#        [ 9.476982 ],
#        [17.680864 ],
#        [12.311952 ],
#        [15.523682 ],
#        [ 9.210702 ],
#        [13.031456 ],
#        [14.497177 ],
#        [11.12381  ],
#        [ 9.610438 ],
#        [15.004914 ],
#        [15.202008 ],
#        [ 8.429357 ],
#        [ 3.975341 ]], dtype=float32), 'neuron_means2': array([[ 9.625937 ],
#        [ 4.5894294],
#        [10.897534 ],
#        [12.230088 ],
#        [11.770218 ],
#        [14.709827 ],
#        [12.227345 ],
#        [ 7.031933 ],
#        [ 4.6598134],
#        [ 8.3653345],
#        [11.988826 ],
#        [12.450639 ],
#        [12.543738 ],
#        [13.050747 ],
#        [12.424056 ],
#        [ 4.885817 ],
#        [11.588203 ],
#        [12.846587 ],
#        [11.481914 ],
#        [ 4.6908255],
#        [ 9.022631 ],
#        [ 7.2993245],
#        [10.95575  ],
#        [12.009388 ],
#        [11.984161 ],
#        [ 9.884557 ],
#        [10.780692 ],
#        [ 8.967256 ],
#        [12.495186 ],
#        [ 9.941417 ],
#        [10.977632 ],
#        [ 8.866649 ],
#        [11.336652 ],
#        [10.107907 ],
#        [11.455956 ],
#        [ 4.673471 ],
#        [ 4.7936387],
#        [ 8.13038  ],
#        [10.968578 ],
#        [ 9.353999 ],
#        [ 5.040026 ],
#        [12.259917 ],
#        [10.816901 ],
#        [11.552627 ],
#        [ 9.196863 ],
#        [ 9.7988615],
#        [ 6.9289207],
#        [13.797574 ],
#        [10.607035 ],
#        [10.476535 ],
#        [13.5161295],
#        [ 4.482144 ],
#        [ 5.97259  ],
#        [ 5.06885  ],
#        [ 8.936478 ],
#        [12.508106 ],
#        [12.096267 ],
#        [13.761046 ],
#        [ 5.0086484],
#        [11.668678 ],
#        [ 4.413732 ],
#        [10.505519 ],
#        [12.889094 ],
#        [ 9.139203 ]], dtype=float32), 'cca_coef1': array([0.98773842, 0.97301305, 0.96535211, 0.94671128, 0.93013471,
#        0.91766492, 0.8881939 , 0.88508108, 0.88092184, 0.84806104,
#        0.81464812, 0.78397497, 0.75511317, 0.72810658, 0.70400625,
#        0.68515149, 0.66770794, 0.64963148, 0.61958946, 0.60496892,
#        0.5966387 , 0.5860084 , 0.5661127 , 0.54409225, 0.51234395,
#        0.50199732, 0.45626898, 0.44745976, 0.42840269, 0.41406495,
#        0.39787245, 0.38427283, 0.37322354, 0.36981461, 0.3573998 ,
#        0.3416742 , 0.33918659, 0.33228705, 0.32091973, 0.28537373,
#        0.27788382, 0.26315725, 0.24778823, 0.23690515, 0.22664377,
#        0.21950689, 0.21544503, 0.20663399, 0.20538815, 0.19185301,
#        0.17558128, 0.16848219, 0.16083917, 0.14103257, 0.13706204,
#        0.12997497, 0.11868849, 0.09359032, 0.08771176, 0.07904064,
#        0.0781911 , 0.07328249, 0.06962329, 0.0591356 ]), 'cca_coef2': array([0.98773842, 0.97301305, 0.96535211, 0.94671128, 0.93013471,
#        0.91766492, 0.8881939 , 0.88508108, 0.88092184, 0.84806104,
#        0.81464812, 0.78397497, 0.75511317, 0.72810658, 0.70400625,
#        0.68515149, 0.66770794, 0.64963148, 0.61958946, 0.60496892,
#        0.5966387 , 0.5860084 , 0.5661127 , 0.54409225, 0.51234395,
#        0.50199732, 0.45626898, 0.44745976, 0.42840269, 0.41406495,
#        0.39787245, 0.38427283, 0.37322354, 0.36981461, 0.3573998 ,
#        0.3416742 , 0.33918659, 0.33228705, 0.32091973, 0.28537373,
#        0.27788382, 0.26315725, 0.24778823, 0.23690515, 0.22664377,
#        0.21950689, 0.21544503, 0.20663399, 0.20538815, 0.19185301,
#        0.17558128, 0.16848219, 0.16083917, 0.14103257, 0.13706204,
#        0.12997497, 0.11868849, 0.09359032, 0.08771176, 0.07904064,
#        0.0781911 , 0.07328249, 0.06962329, 0.0591356 ]), 'x_idxs': array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True]), 'y_idxs': array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True]), 'mean': (np.float64(0.49322896405186456), np.float64(0.49322896405186456)), 'sum': (np.float64(28.65462614480943), np.float64(28.65462614480943))}

# %%
res_path = "/Users/tizianocausin/OneDrive - SISSA/data_repo/exp_set_res/silico"
model_name = "alexnet"
pooling = "maxpool"
target_layer = "classifier.2"
target_layer1 = layer_names[layer_idx1]
feats_path1 = f"{res_path}/imagenet_val_{model_name}_{target_layer1}_{pooling}_features.pkl"
all_acts1 = joblib.load(feats_path1)

# %%
plt.imshow(layers_rsa, cmap='viridis', aspect='auto')
plt.colorbar(label='Value')
for i in range(layers_rsa.shape[0]):
    for j in range(layers_rsa.shape[1]):
        value = layers_rsa[i, j]
        plt.text(j, i, f'{value:.2f}', ha='center', va='center', color='white' if value < 0.5 else 'black')

plt.xlabel('Column')
plt.imsave("/Users/tizianocausin/Desktop/backUp20240609/summer2025/ponce_lab/exp_set/figs/rsa_layers_alexnet.png",layers_rsa, cmap="viridis")

# %%
print(np.mean(results["cca_coef1"]))
print(results["cca_dirns1"].shape)
# Out:
# 0.44772853351264735
# (192, 49152)
